# %% [markdown]
# <a href="https://colab.research.google.com/github/NahidurRahaman/Machine_Learning/blob/main/Facial_Emotion_detection_using_MLP_CNN_CNNBN_ResNet(fer2013).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Imports and Augmentation**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torchvision import models
from torch.utils.data import DataLoader, Dataset
from torch.optim.lr_scheduler import StepLR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

transform_val = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# %% [markdown]
# **FER2013 Custom Dataset Loader**

# %%
class FER2013Dataset(Dataset):
    def __init__(self, csv_file, usage='Training', transform=None):
        self.data = pd.read_csv(csv_file)
        self.data = self.data[self.data['Usage'] == usage]
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        pixels = np.array(self.data.iloc[idx]['pixels'].split(), dtype='float32')
        image = pixels.reshape(48, 48)
        image = Image.fromarray(image).convert("L")
        label = int(self.data.iloc[idx]['emotion'])
        if self.transform:
            image = self.transform(image)
        return image, label

# %% [markdown]
# **Model 1: MLP**

# %%
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.flatten = nn.Flatten()
        # Corrected input size for the first linear layer (1*48*48 = 2304)
        self.fc1 = nn.Linear(48*48, 1024)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(1024, 512)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(512, 256)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(256, 128)
        self.relu4 = nn.ReLU()
        # Corrected output size for the last linear layer (7 classes)
        self.fc5 = nn.Linear(128, 7)

    def forward(self, x):
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        x = self.relu3(x)
        x = self.fc4(x)
        x = self.relu4(x)
        x = self.fc5(x)
        return x

# %% [markdown]
# **Model 2: CNN**

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.fc_layers = nn.Sequential(
            nn.Linear(64 * 10 * 10, 128), # Corrected input size to 6400
            nn.ReLU(),
            nn.Linear(128, 7)
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = x.view(x.size(0), -1)
        return self.fc_layers(x)

# %% [markdown]
# **Model 3: CNN + BatchNorm**

# %%
class CNN_BN(nn.Module):
    def __init__(self):
        super(CNN_BN, self).__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv2d(1, 32, 3),               # -> [32, 46, 46]
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),                   # -> [32, 23, 23]

            nn.Conv2d(32, 64, 3),              # -> [64, 21, 21]
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2)                    # -> [64, 10, 10]
        )
        self.fc_layers = nn.Sequential(
            nn.Linear(64 * 10 * 10, 128),      # ✅ Update shape here: 6400
            nn.ReLU(),
            nn.Linear(128, 7)
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = x.view(x.size(0), -1)
        # print(x.shape)  # Uncomment this line to debug shape
        return self.fc_layers(x)

# %% [markdown]
# **Model 4: Transfer Learning (ResNet18)**

# %%
class ResNetTransfer(nn.Module):
    def __init__(self):
        super(ResNetTransfer, self).__init__()
        base_model = models.resnet18(pretrained=True)
        base_model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        num_features = base_model.fc.in_features
        base_model.fc = nn.Linear(num_features, 7)
        self.model = base_model

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# **Model Instantiate, Optimizer, Scheduler**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_1 = MLP().to(device)  # পরিবর্তন করুন অন্য মডেল অনুযায়ী: MLP(), CNN(), ResNetTransfer()

optimizer = torch.optim.Adam(model_1.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=10, gamma=0.1)

# %% [markdown]
# **Training and Validation Loop**

# %%
def train(model, loader, optimizer, criterion):
    model_1.train()
    total_loss, correct = 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        pred = model(x)
        loss = criterion(pred, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        correct += (pred.argmax(1) == y).sum().item()
    return total_loss / len(loader), correct / len(loader.dataset)

def validate(model, loader, criterion):
    model.eval()
    total_loss, correct = 0, 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            pred = model(x)
            loss = criterion(pred, y)
            total_loss += loss.item()
            correct += (pred.argmax(1) == y).sum().item()
    return total_loss / len(loader), correct / len(loader.dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Dataset Load and Train**

# %%
train_dataset = FER2013Dataset("/content/drive/MyDrive/fer2013.csv", usage='Training', transform=transform_train)
val_dataset = FER2013Dataset("/content/drive/MyDrive/fer2013.csv", usage='PublicTest', transform=transform_val)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

criterion = nn.CrossEntropyLoss()

# Initialize lists to store metrics
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []


for epoch in range(50):
    train_loss, train_acc = train(model_1, train_loader, optimizer, criterion)
    val_loss, val_acc = validate(model_1, val_loader, criterion)

    # Append metrics
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)

    scheduler.step()

    print(f"Epoch {epoch+1}: Train Acc={train_acc:.2f}, Val Acc={val_acc:.2f}")
# Out:
# Epoch 1: Train Acc=0.31, Val Acc=0.36
# Epoch 2: Train Acc=0.37, Val Acc=0.38
# Epoch 3: Train Acc=0.38, Val Acc=0.39
# Epoch 4: Train Acc=0.40, Val Acc=0.41
# Epoch 5: Train Acc=0.41, Val Acc=0.41
# Epoch 6: Train Acc=0.42, Val Acc=0.42
# Epoch 7: Train Acc=0.43, Val Acc=0.41
# Epoch 8: Train Acc=0.44, Val Acc=0.43
# Epoch 9: Train Acc=0.45, Val Acc=0.43
# Epoch 10: Train Acc=0.46, Val Acc=0.43
# Epoch 11: Train Acc=0.49, Val Acc=0.46
# Epoch 12: Train Acc=0.50, Val Acc=0.46
# Epoch 13: Train Acc=0.51, Val Acc=0.46
# Epoch 14: Train Acc=0.52, Val Acc=0.46
# Epoch 15: Train Acc=0.52, Val Acc=0.46
# Epoch 16: Train Acc=0.52, Val Acc=0.46
# Epoch 17: Train Acc=0.53, Val Acc=0.46
# Epoch 18: Train Acc=0.53, Val Acc=0.46
# Epoch 19: Train Acc=0.54, Val Acc=0.46
# Epoch 20: Train Acc=0.55, Val Acc=0.46
# Epoch 21: Train Acc=0.56, Val Acc=0.46
# Epoch 22: Train Acc=0.55, Val Acc=0.46
# Epoch 23: Train Acc=0.56, Val Acc=0.46
# Epoch 24: Train Acc=0.55, Val Acc=0.46
# Epoch 25: Train Acc=0.56, Val Acc=0.46
# Epoch 26: Train Acc=0.56, Val Acc=0.46
# Epoch 27: Train Acc=0.56, Val Acc=0.46
# Epoch 28: Train Acc=0.56, Val Acc=0.46
# Epoch 29: Train Acc=0.56, Val Acc=0.46
# Epoch 30: Train Acc=0.56, Val Acc=0.46
# Epoch 31: Train Acc=0.56, Val Acc=0.46
# Epoch 32: Train Acc=0.56, Val Acc=0.46
# Epoch 33: Train Acc=0.56, Val Acc=0.46
# Epoch 34: Train Acc=0.56, Val Acc=0.46
# Epoch 35: Train Acc=0.56, Val Acc=0.46
# Epoch 36: Train Acc=0.56, Val Acc=0.46
# Epoch 37: Train Acc=0.56, Val Acc=0.46
# Epoch 38: Train Acc=0.56, Val Acc=0.46
# Epoch 39: Train Acc=0.56, Val Acc=0.46
# Epoch 40: Train Acc=0.56, Val Acc=0.46
# Epoch 41: Train Acc=0.56, Val Acc=0.46
# Epoch 42: Train Acc=0.56, Val Acc=0.46
# Epoch 43: Train Acc=0.56, Val Acc=0.46
# Epoch 44: Train Acc=0.56, Val Acc=0.46
# Epoch 45: Train Acc=0.56, Val Acc=0.46
# Epoch 46: Train Acc=0.56, Val Acc=0.46
# Epoch 47: Train Acc=0.56, Val Acc=0.46
# Epoch 48: Train Acc=0.56, Val Acc=0.46
# Epoch 49: Train Acc=0.56, Val Acc=0.46
# Epoch 50: Train Acc=0.56, Val Acc=0.46

# %% [markdown]
# **Plot Accuracy & Loss**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Confusion Matrix & Classification Report**

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import numpy as np

# Make predictions
all_preds = []
all_labels = []

model_1.eval()
with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model_1(images)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=emotion_labels, yticklabels=emotion_labels, cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(all_labels, all_preds, target_names=emotion_labels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.35      0.30      0.33       467
#      Disgust       0.55      0.20      0.29        56
#         Fear       0.35      0.25      0.29       496
#        Happy       0.59      0.68      0.63       895
#          Sad       0.36      0.40      0.38       653
#     Surprise       0.62      0.60      0.61       415
#      Neutral       0.40      0.43      0.41       607
#
#     accuracy                           0.46      3589
#    macro avg       0.46      0.41      0.42      3589
# weighted avg       0.45      0.46      0.45      3589

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_2 = CNN().to(device)  # পরিবর্তন করুন অন্য মডেল অনুযায়ী: MLP(), CNN(), ResNetTransfer()

optimizer = torch.optim.Adam(model_2.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=10, gamma=0.1)

# %%
train_dataset = FER2013Dataset("/content/drive/MyDrive/fer2013.csv", usage='Training', transform=transform_train)
val_dataset = FER2013Dataset("/content/drive/MyDrive/fer2013.csv", usage='PublicTest', transform=transform_val)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

criterion = nn.CrossEntropyLoss()
# Initialize lists to store metrics
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []


for epoch in range(50):
    train_loss, train_acc = train(model_2, train_loader, optimizer, criterion)
    val_loss, val_acc = validate(model_2, val_loader, criterion)

    # Append metrics
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)

    scheduler.step()

    print(f"Epoch {epoch+1}: Train Acc={train_acc:.2f}, Val Acc={val_acc:.2f}")
# Out:
# Epoch 1: Train Acc=0.38, Val Acc=0.45
# Epoch 2: Train Acc=0.47, Val Acc=0.47
# Epoch 3: Train Acc=0.50, Val Acc=0.51
# Epoch 4: Train Acc=0.53, Val Acc=0.53
# Epoch 5: Train Acc=0.55, Val Acc=0.54
# Epoch 6: Train Acc=0.56, Val Acc=0.55
# Epoch 7: Train Acc=0.58, Val Acc=0.56
# Epoch 8: Train Acc=0.59, Val Acc=0.56
# Epoch 9: Train Acc=0.60, Val Acc=0.57
# Epoch 10: Train Acc=0.61, Val Acc=0.57
# Epoch 11: Train Acc=0.64, Val Acc=0.57
# Epoch 12: Train Acc=0.65, Val Acc=0.57
# Epoch 13: Train Acc=0.65, Val Acc=0.58
# Epoch 14: Train Acc=0.65, Val Acc=0.58
# Epoch 15: Train Acc=0.65, Val Acc=0.58
# Epoch 16: Train Acc=0.66, Val Acc=0.58
# Epoch 17: Train Acc=0.66, Val Acc=0.58
# Epoch 18: Train Acc=0.66, Val Acc=0.57
# Epoch 19: Train Acc=0.66, Val Acc=0.58
# Epoch 20: Train Acc=0.67, Val Acc=0.58
# Epoch 21: Train Acc=0.67, Val Acc=0.58
# Epoch 22: Train Acc=0.67, Val Acc=0.58
# Epoch 23: Train Acc=0.67, Val Acc=0.58
# Epoch 24: Train Acc=0.67, Val Acc=0.58
# Epoch 25: Train Acc=0.67, Val Acc=0.58
# Epoch 26: Train Acc=0.67, Val Acc=0.58
# Epoch 27: Train Acc=0.67, Val Acc=0.58
# Epoch 28: Train Acc=0.67, Val Acc=0.58
# Epoch 29: Train Acc=0.67, Val Acc=0.58
# Epoch 30: Train Acc=0.67, Val Acc=0.58
# Epoch 31: Train Acc=0.67, Val Acc=0.58
# Epoch 32: Train Acc=0.67, Val Acc=0.58
# Epoch 33: Train Acc=0.67, Val Acc=0.58
# Epoch 34: Train Acc=0.67, Val Acc=0.58
# Epoch 35: Train Acc=0.67, Val Acc=0.58
# Epoch 36: Train Acc=0.67, Val Acc=0.58
# Epoch 37: Train Acc=0.67, Val Acc=0.58
# Epoch 38: Train Acc=0.67, Val Acc=0.58
# Epoch 39: Train Acc=0.68, Val Acc=0.58
# Epoch 40: Train Acc=0.68, Val Acc=0.58
# Epoch 41: Train Acc=0.67, Val Acc=0.58
# Epoch 42: Train Acc=0.67, Val Acc=0.58
# Epoch 43: Train Acc=0.67, Val Acc=0.58
# Epoch 44: Train Acc=0.67, Val Acc=0.58
# Epoch 45: Train Acc=0.67, Val Acc=0.58
# Epoch 46: Train Acc=0.67, Val Acc=0.58
# Epoch 47: Train Acc=0.67, Val Acc=0.58
# Epoch 48: Train Acc=0.68, Val Acc=0.58
# Epoch 49: Train Acc=0.68, Val Acc=0.58
# Epoch 50: Train Acc=0.67, Val Acc=0.58

# %%
plt.figure(figsize=(14, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import numpy as np
# Make predictions
all_preds = []
all_labels = []

model_2.eval()
with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model_2(images)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=emotion_labels, yticklabels=emotion_labels, cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(all_labels, all_preds, target_names=emotion_labels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.46      0.46      0.46       467
#      Disgust       0.69      0.43      0.53        56
#         Fear       0.45      0.35      0.40       496
#        Happy       0.77      0.81      0.79       895
#          Sad       0.45      0.47      0.46       653
#     Surprise       0.72      0.75      0.74       415
#      Neutral       0.50      0.54      0.52       607
#
#     accuracy                           0.58      3589
#    macro avg       0.58      0.54      0.55      3589
# weighted avg       0.57      0.58      0.58      3589

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_3 = CNN_BN().to(device)  # পরিবর্তন করুন অন্য মডেল অনুযায়ী: MLP(), CNN(), ResNetTransfer()

optimizer = torch.optim.Adam(model_3.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=10, gamma=0.1)

# %%
train_dataset = FER2013Dataset("/content/drive/MyDrive/fer2013.csv", usage='Training', transform=transform_train)
val_dataset = FER2013Dataset("/content/drive/MyDrive/fer2013.csv", usage='PublicTest', transform=transform_val)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

criterion = nn.CrossEntropyLoss()
# Initialize lists to store metrics
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []


for epoch in range(50):
    train_loss, train_acc = train(model_3, train_loader, optimizer, criterion)
    val_loss, val_acc = validate(model_3, val_loader, criterion)

    # Append metrics
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)

    scheduler.step()

    print(f"Epoch {epoch+1}: Train Acc={train_acc:.2f}, Val Acc={val_acc:.2f}")
# Out:
# Epoch 1: Train Acc=0.37, Val Acc=0.46
# Epoch 2: Train Acc=0.47, Val Acc=0.50
# Epoch 3: Train Acc=0.51, Val Acc=0.53
# Epoch 4: Train Acc=0.53, Val Acc=0.53
# Epoch 5: Train Acc=0.55, Val Acc=0.54
# Epoch 6: Train Acc=0.56, Val Acc=0.55
# Epoch 7: Train Acc=0.57, Val Acc=0.55
# Epoch 8: Train Acc=0.59, Val Acc=0.55
# Epoch 9: Train Acc=0.59, Val Acc=0.56
# Epoch 10: Train Acc=0.60, Val Acc=0.55
# Epoch 11: Train Acc=0.63, Val Acc=0.56
# Epoch 12: Train Acc=0.64, Val Acc=0.56
# Epoch 13: Train Acc=0.64, Val Acc=0.56
# Epoch 14: Train Acc=0.65, Val Acc=0.57
# Epoch 15: Train Acc=0.65, Val Acc=0.56
# Epoch 16: Train Acc=0.65, Val Acc=0.57
# Epoch 17: Train Acc=0.65, Val Acc=0.57
# Epoch 18: Train Acc=0.65, Val Acc=0.57
# Epoch 19: Train Acc=0.65, Val Acc=0.57
# Epoch 20: Train Acc=0.66, Val Acc=0.57
# Epoch 21: Train Acc=0.66, Val Acc=0.57
# Epoch 22: Train Acc=0.66, Val Acc=0.57
# Epoch 23: Train Acc=0.66, Val Acc=0.57
# Epoch 24: Train Acc=0.66, Val Acc=0.57
# Epoch 25: Train Acc=0.67, Val Acc=0.57
# Epoch 26: Train Acc=0.66, Val Acc=0.57
# Epoch 27: Train Acc=0.66, Val Acc=0.57
# Epoch 28: Train Acc=0.67, Val Acc=0.57
# Epoch 29: Train Acc=0.66, Val Acc=0.57
# Epoch 30: Train Acc=0.67, Val Acc=0.57
# Epoch 31: Train Acc=0.67, Val Acc=0.57
# Epoch 32: Train Acc=0.66, Val Acc=0.57
# Epoch 33: Train Acc=0.67, Val Acc=0.57
# Epoch 34: Train Acc=0.67, Val Acc=0.57
# Epoch 35: Train Acc=0.67, Val Acc=0.57
# Epoch 36: Train Acc=0.67, Val Acc=0.57
# Epoch 37: Train Acc=0.67, Val Acc=0.57
# Epoch 38: Train Acc=0.67, Val Acc=0.57
# Epoch 39: Train Acc=0.66, Val Acc=0.57
# Epoch 40: Train Acc=0.67, Val Acc=0.57
# Epoch 41: Train Acc=0.67, Val Acc=0.57
# Epoch 42: Train Acc=0.67, Val Acc=0.57
# Epoch 43: Train Acc=0.66, Val Acc=0.57
# Epoch 44: Train Acc=0.67, Val Acc=0.57
# Epoch 45: Train Acc=0.66, Val Acc=0.57
# Epoch 46: Train Acc=0.67, Val Acc=0.57
# Epoch 47: Train Acc=0.66, Val Acc=0.57
# Epoch 48: Train Acc=0.67, Val Acc=0.57
# Epoch 49: Train Acc=0.66, Val Acc=0.57
# Epoch 50: Train Acc=0.66, Val Acc=0.57

# %%
plt.figure(figsize=(14, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Make predictions
all_preds = []
all_labels = []

model_3.eval()
with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model_3(images)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=emotion_labels, yticklabels=emotion_labels, cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(all_labels, all_preds, target_names=emotion_labels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.48      0.45      0.47       467
#      Disgust       0.56      0.43      0.48        56
#         Fear       0.44      0.31      0.37       496
#        Happy       0.77      0.79      0.78       895
#          Sad       0.42      0.49      0.45       653
#     Surprise       0.71      0.73      0.72       415
#      Neutral       0.49      0.51      0.50       607
#
#     accuracy                           0.57      3589
#    macro avg       0.55      0.53      0.54      3589
# weighted avg       0.56      0.57      0.56      3589

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_4 = ResNetTransfer().to(device)  # পরিবর্তন করুন অন্য মডেল অনুযায়ী: MLP(), CNN(), ResNetTransfer()

optimizer = torch.optim.Adam(model_4.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=10, gamma=0.1)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
train_dataset = FER2013Dataset("/content/drive/MyDrive/fer2013.csv", usage='Training', transform=transform_train)
val_dataset = FER2013Dataset("/content/drive/MyDrive/fer2013.csv", usage='PublicTest', transform=transform_val)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

criterion = nn.CrossEntropyLoss()

# Initialize lists to store metrics
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []


for epoch in range(50):
    train_loss, train_acc = train(model_4, train_loader, optimizer, criterion)
    val_loss, val_acc = validate(model_4, val_loader, criterion)

    # Append metrics
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)

    scheduler.step()

    print(f"Epoch {epoch+1}: Train Acc={train_acc:.2f}, Val Acc={val_acc:.2f}")
# Out:
# Epoch 1: Train Acc=0.39, Val Acc=0.46
# Epoch 2: Train Acc=0.37, Val Acc=0.46
# Epoch 3: Train Acc=0.46, Val Acc=0.49
# Epoch 4: Train Acc=0.50, Val Acc=0.52
# Epoch 5: Train Acc=0.53, Val Acc=0.52
# Epoch 6: Train Acc=0.54, Val Acc=0.55
# Epoch 7: Train Acc=0.56, Val Acc=0.56
# Epoch 8: Train Acc=0.58, Val Acc=0.57
# Epoch 9: Train Acc=0.59, Val Acc=0.57
# Epoch 10: Train Acc=0.60, Val Acc=0.58
# Epoch 11: Train Acc=0.66, Val Acc=0.59
# Epoch 12: Train Acc=0.68, Val Acc=0.61
# Epoch 13: Train Acc=0.68, Val Acc=0.61
# Epoch 14: Train Acc=0.69, Val Acc=0.60
# Epoch 15: Train Acc=0.70, Val Acc=0.60
# Epoch 16: Train Acc=0.71, Val Acc=0.60
# Epoch 17: Train Acc=0.72, Val Acc=0.60
# Epoch 18: Train Acc=0.73, Val Acc=0.60
# Epoch 19: Train Acc=0.74, Val Acc=0.60
# Epoch 20: Train Acc=0.75, Val Acc=0.59
# Epoch 21: Train Acc=0.77, Val Acc=0.60
# Epoch 22: Train Acc=0.78, Val Acc=0.60
# Epoch 23: Train Acc=0.78, Val Acc=0.60
# Epoch 24: Train Acc=0.78, Val Acc=0.60
# Epoch 25: Train Acc=0.78, Val Acc=0.60
# Epoch 26: Train Acc=0.78, Val Acc=0.60
# Epoch 27: Train Acc=0.78, Val Acc=0.60
# Epoch 28: Train Acc=0.78, Val Acc=0.60
# Epoch 29: Train Acc=0.79, Val Acc=0.60
# Epoch 30: Train Acc=0.79, Val Acc=0.60
# Epoch 31: Train Acc=0.79, Val Acc=0.60
# Epoch 32: Train Acc=0.79, Val Acc=0.60
# Epoch 33: Train Acc=0.79, Val Acc=0.60
# Epoch 34: Train Acc=0.79, Val Acc=0.60
# Epoch 35: Train Acc=0.79, Val Acc=0.60
# Epoch 36: Train Acc=0.79, Val Acc=0.60
# Epoch 37: Train Acc=0.79, Val Acc=0.60
# Epoch 38: Train Acc=0.79, Val Acc=0.60
# Epoch 39: Train Acc=0.79, Val Acc=0.60
# Epoch 40: Train Acc=0.79, Val Acc=0.60
# Epoch 41: Train Acc=0.80, Val Acc=0.60
# Epoch 42: Train Acc=0.79, Val Acc=0.60
# Epoch 43: Train Acc=0.79, Val Acc=0.60
# Epoch 44: Train Acc=0.79, Val Acc=0.60
# Epoch 45: Train Acc=0.79, Val Acc=0.60
# Epoch 46: Train Acc=0.79, Val Acc=0.60
# Epoch 47: Train Acc=0.79, Val Acc=0.60
# Epoch 48: Train Acc=0.79, Val Acc=0.60
# Epoch 49: Train Acc=0.79, Val Acc=0.60
# Epoch 50: Train Acc=0.79, Val Acc=0.60

# %%
plt.figure(figsize=(14, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import numpy as np

# Make predictions
all_preds = []
all_labels = []

model_4.eval()
with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model_4(images)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=emotion_labels, yticklabels=emotion_labels, cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(all_labels, all_preds, target_names=emotion_labels))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.51      0.54      0.52       467
#      Disgust       0.77      0.43      0.55        56
#         Fear       0.43      0.38      0.40       496
#        Happy       0.81      0.82      0.82       895
#          Sad       0.49      0.46      0.48       653
#     Surprise       0.75      0.75      0.75       415
#      Neutral       0.49      0.56      0.52       607
#
#     accuracy                           0.60      3589
#    macro avg       0.61      0.56      0.58      3589
# weighted avg       0.60      0.60      0.60      3589
